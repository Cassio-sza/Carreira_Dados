# %% [markdown]
# # Banco de dado e SQL para Análise de Dados com PostgesSQL

# %% [markdown]
# - Nas empresas, os dados são guardade em **bancos de dados relacionais**;
# - Os gerenciadores de bancs de dados mais famosos são o Oracle, MySQL, Microsoft SQL Server, PostgreSQL e IMB DB2;
# - Precisamos instalar na máquina tanto o pacote postgesSQL quanto seu interpretador python psycopg2;

# %%
import psycopg2
