# %% [markdown]
# - Monte o seu questionário de pesquisa com no mínimo 5 perguntas;
# - Insira 3 perguntas quantitativas e duas qualitativas;

# %% [markdown]
# ## Perguntas
#
# 1. **Quantos dias por semana você ouve música?** (Quantitativa)
#
#     - Patrícia: 6
#     - Eduardo: 4
#     - Cleber: 3
#     - Letícia: 4
#     - Júlia: 5
#
# 2. **Quantas horas por dia você ouve música?** (Quantitativa)
#
#     - Patrícia: 8
#     - Eduardo: 5
#     - Cleber:  2
#     - Letícia: 3
#     - Júlia:4
#
# 3. **Quantas música você escuta em média por semana?** (Quantitativa)
#
#     - Patrícia: 15
#     - Eduardo: 25
#     - Cleber: 38
#     - Letícia: 22
#     - Júlia: 18
#
# 4. **Quais estilos de música você mais ouve?** (Qualitativa)
#
#     - Patrícia: 'Forró', 'Sertanejo'
#     - Eduardo: 'Pop', 'MPB', 'Samba'
#     - Cleber: 'eletrônica', 'Rap', 'MPB'
#     - Letícia: 'Pop', 'Forró', 'Samba'
#     - Júlia: 'Samba', 'Pop', 'Sertanejo'
#
# 5. **Quais estilos de música você não gosta e evita ouvir?** (Qualitativa)
#
#     - Patrícia: 'Funk'
#     - Eduardo: 'Sertanejo', 'Rap'
#     - Cleber: 'Gospel', 'Sertanejo'
#     - Letícia: 'Rock'
#     - Júlia: 'Gospel'

# %% [markdown]
# Agora, com base nos dados que você escolheu e recolheu
#
# 1. Escolha o tipo de gráfico mais adequado aos dados da sua apresentação
# 2. Selecione quais são as informações necessárias para inserir e quais não são.

# %%
#Importar bibliotecas

import pandas as pd


# Criar dataframe

data = {
    'Nome': ['Patrícia', 'Eduardo', 'Cleber', 'Letícia', 'Júlia'],
    'HorasPorDia': [8, 5, 2, 3, 4],
    'PorDia': [6, 4, 3, 4, 5],
    'PorSemana': [15, 25, 38, 22, 18],
    'EstilosGosta': [['Forró', 'Sertanejo'],['Pop', 'MPB', 'Samba'],['Eletrônica', 'Rap', 'MPB'], ['Pop', 'Forró', 'Samba'], ['Samba', 'Pop', 'Sertanejo']],
    'EstiloNãoGosta': [['Funk'], ['Sertanejo', 'Rap'], ['Gospel', 'Sertanejo'], ['Rock'], ['Gospel']]
}

df = pd.DataFrame(data)

print(df)
# Out:
#        Nome  HorasPorDia  PorDia  PorSemana             EstilosGosta  \
# 0  Patrícia            8       6         15       [Forró, Sertanejo]
# 1   Eduardo            5       4         25        [Pop, MPB, Samba]
# 2    Cleber            2       3         38   [Eletrônica, Rap, MPB]
# 3   Letícia            3       4         22      [Pop, Forró, Samba]
# 4     Júlia            4       5         18  [Samba, Pop, Sertanejo]
#
#         EstiloNãoGosta
# 0               [Funk]
# 1     [Sertanejo, Rap]
# 2  [Gospel, Sertanejo]
# 3               [Rock]
# 4             [Gospel]

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Nome            5 non-null      str
#  1   HorasPorDia     5 non-null      int64
#  2   PorDia          5 non-null      int64
#  3   PorSemana       5 non-null      int64
#  4   EstilosGosta    5 non-null      object
#  5   EstiloNãoGosta  5 non-null      object
# dtypes: int64(3), object(2), str(1)
# memory usage: 372.0+ bytes

# %%
print(df['EstilosGosta'])
# Out:
# 0         [Forró, Sertanejo]
# 1          [Pop, MPB, Samba]
# 2     [Eletrônica, Rap, MPB]
# 3        [Pop, Forró, Samba]
# 4    [Samba, Pop, Sertanejo]
# Name: EstilosGosta, dtype: object
